# %%
from dotenv import load_dotenv
load_dotenv()

from main import run_agent
from tools.dependencies import build_deps

# %%
result = await run_agent("Give me a 3-sentence overview of the EU AI Act.")
print(result.output)

# %%
result = await run_agent("Would the use of an AI-based decision-support system for truck tire retreading count as a high-risk application according to the EU AI Act?")
print(result.output)
# Out:
# It appears that I was unable to retrieve specific definitions or articles from the EU AI Act pertaining to high-risk AI applications. However, I can provide some general insights based on the typical criteria used to evaluate whether an AI application is considered high-risk under the EU AI Act.
#
# ### Summary
# The EU AI Act categorizes AI systems into different risk levels: minimal risk, limited risk, high risk, and unacceptable risk. High-risk AI applications are subject to stricter regulations and oversight.
#
# ### Applicability
# To determine whether the use of an AI-based decision-support system for truck tire retreading is considered high-risk, one would typically assess several factors:
#
# 1. **Sector-Specific Use**: The application of AI in critical sectors such as transport and safety may elevate the risk classification.
# ...

# %%
result = await run_agent("How is AI regulated under Trump?")
print(result.output)
# Out:
# ### Summary
# Under the Trump administration, AI regulation was characterized by a shift towards minimizing federal oversight and empowering the federal government to preempt state-level regulations. Significant actions were taken, including executive orders aimed at creating a unified national policy for artificial intelligence, which criticized state regulations as burdensome and promoting a fragmented regulatory landscape. This approach contrasts sharply with the more cautious regulatory framework established during the Biden administration, which emphasized accountability, equity, and oversight.
#
# ### Applicability
# ...

# %%
result = await run_agent("What are Oliver Patel's top 5 practical steps to mitigate risks related to AI and copyright?")
print(result.output)
# Out:
# Here are Oliver Patel's top 5 practical tips for compliance with prohibited AI practices, particularly in light of the EU AI Act:
#
# 1. **Company-wide Communications and Training:**
#    Implement comprehensive training and awareness campaigns throughout the organization to educate employees on prohibited AI practices. Given that the AI Act's implications are relatively new, ensure that all staff, not just AI specialists, understand the prohibitions and their potential impacts.
#
# 2. **Assess Jurisdictional Implications:**
#    Determine how the definitions of prohibited AI practices under the EU AI Act intersect with regulations in other jurisdictions. Understanding this can help prevent conflicts and ensure compliance across different regions where your AI systems may operate.
#
# 3. **Robust AI Governance Framework:**
# ...

# %%
result = await run_agent("How is agentic AI regulated in Singapore?")
print(result.output)

# %%
result = await run_agent("In their paper, Luca Nannini et al. develop a practical taxonomy of nine agent deployment categories mapping concrete actions to regulatory triggers. What is their taxonomy?")
print(result.output)
# Out:
# ### Summary
# Luca Nannini et al. present a practical taxonomy that categorizes AI agent deployments into nine categories, linking specific actions to relevant regulatory triggers within the European Union. This taxonomy aids compliance by clarifying the regulatory landscape as it pertains to various use cases of AI agents.
#
# ### Applicability
# The taxonomy is designed for AI agents operating within the EU, specifically concerning the implications of the **EU AI Act** and other related regulatory frameworks, such as the **GDPR** and the **Digital Services Act (DSA)**.
#
# ### Key Requirements
# The taxonomy details how each agent category corresponds to concrete actions, external system dependencies, and the specific regulatory triggers they activate. Here's a breakdown of the categories and their respective actions:
#
# 1. **Customer Service**
# ...

# %%
result = await run_agent("According to Kauffman, how should the TechTronics Inc. approach the EU market?")
print(result.output)
# Out:
# ### Summary
# Marcos Kauffman's insights on TechTronics Inc.’s approach to the European market suggest a strategic focus on compliance with the EU AI Act and local regulations. The company must leverage local partnerships while ensuring its products meet EU safety benchmarks to effectively compete in this unique market.
#
# ### Applicability
# TechTronics operates in a sector subject to the EU's rigorous standards, specifically in areas related to AI and robotics. As the EU expands its regulatory landscape, particularly with the AI Act, TechTronics must adapt its business practices accordingly.
#
# ### Key Requirements
# 1. **Compliance with EU AI Act**: The act categorizes many AI systems as high-risk and mandates strict compliance, particularly in terms of safety and transparency.
# 2. **Documentation and Governance**: TechTronics needs to ensure comprehensive documentation that adheres to EU data governance and safety requirements.
# ...
