# %% [markdown]
# ## Demo notebook

# %%
from dotenv import load_dotenv
load_dotenv()

from main import run_agent
from tools.dependencies import build_deps

# %%
result = await run_agent("What is the Trump administration's approach to regulating AI for military applications?")
print(result.output)
# Out:
# ### Summary
# The Trump administration's approach to regulating artificial intelligence (AI) for military applications was characterized by a focus on promoting innovation while minimizing regulatory complexities and ensuring national security interests. Key initiatives included the creation of uniform federal regulations to streamline compliance for defense contractors and the establishment of an AI Action Plan to enhance AI integration into military operations.
#
# ### Applicability
# This regulatory approach primarily applied to the Department of Defense (DoD), defense contractors, and entities engaged in AI research and development relevant to military applications.
#
# ### Key Requirements
# 1. **Uniform Federal Rules**: The administration sought to replace state-by-state compliance requirements with a single federal framework, which would simplify compliance for defense contractors and promote faster deployment of AI technologies.
#
# ...

# %%
result = await run_agent("How is generative AI regulated in Singapore? What are the pros and cons of the Singaporean approach versus the European and Chineses approaches?")
print(result.output)
# Out:
# ### Summary
# Singapore adopts a pragmatic and flexible approach to regulate generative AI, focusing on sector-specific guidelines rather than comprehensive legislation. This strategy allows for rapid adaptation to technological advancements while ensuring responsible AI use. In contrast, the European Union (EU) implements more stringent and universally applicable regulations through the AI Act, emphasizing risk classification and consumer protection, while China's regulatory framework prioritizes state control and the real-time monitoring of AI technologies.
#
# ### Applicability
# - **Singapore**: No specific laws directly regulate AI, but frameworks like the *Model AI Governance Framework* and sector-specific guidelines (e.g., for financial services and healthcare) are in place to promote responsible AI use.
# ...
