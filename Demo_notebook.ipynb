# %%
from dotenv import load_dotenv
load_dotenv()

from main import run_agent
from tools.dependencies import build_deps

# %%
result = await run_agent("Give me a 3-sentence overview of the EU AI Act.")
print(result.output)

# %%
result = await run_agent("Would the use of an AI-based decision-support system for truck tire retreading count as a high-risk application according to the EU AI Act?")
print(result.output)
# Out:
# RAG index already exists.
# ### Summary
# The classification of an AI-based decision-support system for truck tire retreading as a high-risk application according to the EU AI Act depends on specific criteria outlined in the legislation. The AI Act employs a distinction based on the potential risks associated with the use of AI systems. A system would be deemed high-risk if it is involved in safety-critical applications or falls under certain categories defined in the legislation.
#
# ### Applicability
# Under Article 6 of the EU AI Act, an AI system is considered high-risk if it meets one of the following criteria:
#
# - **Safety Component**: It serves as a safety component of a product covered by specific EU legislation listed in Annex I.
# - **Direct Product**: It is a product itself that is covered by such EU legislation and requires third-party assessments.
#
# ### Key Requirements
# ...

# %%
result = await run_agent("How is AI regulated under Trump?")
print(result.output)
# Out:
# RAG index already exists.
# ### Summary
# During Donald Trump's presidency, there were significant initiatives aimed at defining and regulating artificial intelligence (AI) within the United States. His administration focused on minimizing state-level regulations and promoting federal standards. This culminated in several executive orders intended to create a cohesive national framework for AI, reflecting a preference for federal oversight over a patchwork of state laws.
#
# ### Applicability
# The Trump administration's AI regulatory framework primarily affected technology companies engaged in AI development, as well as state governments attempting to establish their own AI regulations. The goal was to ensure that federal policy would guide AI's evolution without local variations complicating the landscape for businesses.
#
# ### Key Requirements
# 1. **Executive Orders**: Key initiatives included:
# ...

# %%
result = await run_agent("What are Oliver Patel's top 5 tips for prohibited AI compliance?")
print(result.output)
# Out:
# RAG index already exists.
# ### Summary
# Oliver Patel offers practical guidance for compliance with the prohibitions outlined in the EU AI Act. Here are his top five tips for effectively navigating these compliance requirements.
#
# ### Top 5 Tips for Prohibited AI Compliance
# 1. **Company-wide Communication and Training**:
#    - Implement continuous communication and training initiatives focused on prohibited AI practices. Given that AI regulation is relatively new, it is essential to educate staff across the organization about the compliance requirements and potential implications of the EU AI Act.
#
# 2. **Understand the Scope of Prohibitions**:
#    - It’s crucial to evaluate which AI systems are prohibited not just in the EU but also in other jurisdictions where your organization operates. This involves a thorough analysis of legal and ethical considerations surrounding the deployment of AI technologies.
#
# 3. **Establish Robust Governance Frameworks**:
# ...

# %%
result = await run_agent("How is agentic AI regulated in Singapore?")
print(result.output)
# Out:
# RAG index already exists.
# ### Summary
#
# Singapore is taking a proactive and pragmatic approach to regulate agentic AI, characterized by a focus on business-friendly guidance and established frameworks. The country's Infocomm Media Development Authority (IMDA) has launched a specific governance framework for agentic AI, aiming to address the unique challenges posed by AI systems capable of autonomous reasoning and action.
#
# ### Applicability
#
# The Model AI Governance Framework for Agentic AI applies to organizations that utilize or plan to utilize agentic AI technologies within their operations. This includes firms in various sectors that may adopt AI systems capable of autonomous decision-making and actions.
#
# ### Key Requirements
#
# 1. **Transparency**: Organizations must ensure that their use of agentic AI is transparent to stakeholders, including clear communication regarding the capabilities and limitations of these AI systems.
#
# ...

# %%
result = await run_agent("What is a NIST definition of 'autonomic'?")
print(result.output)
