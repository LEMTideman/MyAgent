# %%
from dotenv import load_dotenv
load_dotenv()

from main import run_agent
from tools.dependencies import build_deps

# %%
#async def test_agent(prompt: str):
#    deps = build_deps()
#    async with agent:
#        result = await agent.run(prompt, deps=deps)
#    return result

# %%
#result = await test_agent("Give me a 3-sentence overview of the EU AI Act.")
result = await run_agent("Give me a 3-sentence overview of the EU AI Act.")
print(result.output)

# %%
result = await run_agent("How does singaporian AI regulation differ from European AI regulation?")
print(result.output)
# Out:
# RAG index already exists.
# ### Summary
# Singapore and the European Union take fundamentally different approaches to AI regulation. Singapore’s framework is based on voluntary and sector-specific guidelines without comprehensive legislation, while the European Union is advancing a formal, comprehensive AI Act that categorizes AI technologies based on risk and enforces specific obligations.
#
# ### Applicability
# - **Singapore**: No specific laws directly regulate AI currently. Instead, the country offers a governance framework that promotes voluntary adoption of non-binding guidelines and sector-specific regulations.
# - **European Union**: The AI Act applies broadly to AI systems in all member states and imposes strict compliance obligations based on risk categorization.
#
# ### Key Requirements
# 1. **Singapore**:
#    - The regulatory framework incentivizes organizations to adopt best practices voluntarily.
# ...

# %%
result = await run_agent("What is the BSI group's interpretation of the AI Act?")
print(result.output)

# %%
result = await run_agent("What are Oliver Patel's top 5 tips for prohibited AI compliance?")
print(result.output)
# Out:
# RAG index already exists.
# It seems that I encountered issues retrieving specific content from Oliver Patel's sources about prohibited AI compliance. However, I found relevant articles in his Substack that likely discuss tips and guidance regarding compliance in the context of prohibited AI practices.
#
# Here are some key points that are generally emphasized regarding compliance with prohibited AI practices:
#
# 1. **Education and Training**: Ensuring all employees are educated on compliance obligations and the risks associated with AI technologies is crucial. Employees should understand how their use of AI may have compliance implications.
#
# 2. **Robust Compliance Framework**: Establishing a solid compliance framework, including monitoring and audit processes, is necessary to catch any inadvertent uses of prohibited AI technologies.
#
# ...
