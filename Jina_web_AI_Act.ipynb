# %% [markdown]
# ### Notebook for processing the AI Act available on the AI Act Explorer
#
# AI Act Explorer link: https://ai-act-service-desk.ec.europa.eu/en/ai-act-explorer
#
# Download the articles, recitals, and annexes using their respective urls.

# %%
import os
import re
import json
import time
import hashlib
import requests
from pathlib import Path
from dataclasses import dataclass, asdict
from typing import Any, Dict, Iterable, Optional, Tuple
from dotenv import load_dotenv

load_dotenv()  # loads .env from the current working directory

api_key = os.getenv("JINA_API_KEY")
if not api_key:
    raise RuntimeError("JINA_API_KEY not found in .env")

# %%
# ----------------------------
# Data model / utilities
# ----------------------------

@dataclass
class RagDoc:
    doc_id: str
    source_type: str          # "web" or "local_pdf"
    source: str               # URL or local path
    title: str
    text: str
    fetched_at_utc: str
    sha256: str
    meta: Dict[str, Any]


def utc_now_iso() -> str:
    return time.strftime("%Y-%m-%dT%H:%M:%SZ", time.gmtime())


def sha256_text(s: str) -> str:
    return hashlib.sha256(s.encode("utf-8", errors="ignore")).hexdigest()


def safe_slug(s: str, max_len: int = 80) -> str:
    s = s.strip().lower()
    s = re.sub(r"https?://", "", s)
    s = re.sub(r"[^a-z0-9]+", "-", s).strip("-")
    return s[:max_len] if s else "doc"


def ensure_dirs(base: Path) -> Tuple[Path, Path]:
    web_dir = base / "data" / "web"
    web_dir.mkdir(parents=True, exist_ok=True)
    return web_dir

def write_doc(out_dir: Path, doc: RagDoc) -> None:
    # Per-doc files
    json_path = out_dir / f"{doc.doc_id}.json"
    txt_path = out_dir / f"{doc.doc_id}.txt"

    with json_path.open("w", encoding="utf-8") as f:
        json.dump(asdict(doc), f, ensure_ascii=False, indent=2)

    with txt_path.open("w", encoding="utf-8") as f:
        f.write(doc.text or "")

    # Append to jsonl (easy bulk loading)
    jsonl_path = out_dir / "docs.jsonl"
    with jsonl_path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(asdict(doc), ensure_ascii=False) + "\n")


def make_doc_id(prefix: str, source: str, content_hash: str) -> str:
    slug = safe_slug(source)
    short = content_hash[:12] if content_hash else "nohash"
    return f"{prefix}-{slug}-{short}"

def load_processed_urls(index_path: Path) -> set[str]:
    """
    Loads a set of processed URLs from a jsonl file:
    each line is {"url": "...", ...}.
    """
    processed: set[str] = set()
    if not index_path.exists():
        return processed

    with index_path.open("r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                obj = json.loads(line)
                url = obj.get("url")
                if url:
                    processed.add(url)
            except json.JSONDecodeError:
                # ignore corrupt lines instead of crashing
                continue
    return processed


def mark_url_processed(index_path: Path, url: str, doc_id: str, sha256: str) -> None:
    """
    Appends one record per successfully written doc.
    """
    record = {
        "url": url,
        "doc_id": doc_id,
        "sha256": sha256,
        "processed_at_utc": utc_now_iso(),
    }
    with index_path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

# %%
# ----------------------------
# Jina Reader client
# ----------------------------

class JinaReader:
    """
    Jina Reader API:
      - Read URL:    POST https://r.jina.ai/      JSON {"url": "..."}
      - Upload file: POST https://r.jina.ai/upload multipart field "file"
      - Request JSON response: Accept: application/json
      - Auth: Authorization: Bearer <JINA_API_KEY>
    """

    def __init__(self, api_key: str, eu: bool = False, timeout_s: int = 90):
        if not api_key:
            raise ValueError("JINA_API_KEY is required for Jina-only local PDF ingestion.")
        self.api_key = api_key
        self.timeout_s = timeout_s
        self.base = "https://eu.r.jina.ai" if eu else "https://r.jina.ai"

    def _headers(self, extra: Optional[Dict[str, str]] = None) -> Dict[str, str]:
        h = {
            "Accept": "application/json",
            "Authorization": f"Bearer {self.api_key}",
        }
        if extra:
            h.update(extra)
        return h

    def read_url(
        self,
        url: str,
        *,
        engine: str = "browser",
        no_cache: bool = True,
        respond_with: Optional[str] = None,  # e.g. "readerlm-v2"
        remove_selector: Optional[str] = None,
        target_selector: Optional[str] = None,
    ) -> Dict[str, Any]:
        headers: Dict[str, str] = {
            "Content-Type": "application/json",
            "X-Engine": engine,
            "X-No-Cache": "true" if no_cache else "false",
        }
        if respond_with:
            headers["X-Respond-With"] = respond_with
        if remove_selector:
            headers["X-Remove-Selector"] = remove_selector
        if target_selector:
            headers["X-Target-Selector"] = target_selector

        r = requests.post(
            f"{self.base}/",
            headers=self._headers(headers),
            json={"url": url},
            timeout=self.timeout_s,
        )
        r.raise_for_status()
        return r.json()

    def upload_pdf(
        self,
        pdf_path: Path,
        *,
        engine: str = "browser",
        no_cache: bool = True,
        respond_with: Optional[str] = None,
    ) -> Dict[str, Any]:
        headers: Dict[str, str] = {
            "X-Engine": engine,
            "X-No-Cache": "true" if no_cache else "false",
        }
        if respond_with:
            headers["X-Respond-With"] = respond_with

        with pdf_path.open("rb") as f:
            files = {"file": (pdf_path.name, f, "application/pdf")}
            r = requests.post(
                f"{self.base}/upload",
                headers=self._headers(headers),
                files=files,
                timeout=self.timeout_s,
            )
        r.raise_for_status()
        return r.json()

# %%
# ----------------------------
# Ingest routines (Jina-only)
# ----------------------------
def ingest_web_urls(
    reader: JinaReader,
    urls: Iterable[str],
    out_dir: Path,
    *,
    readerlm_v2: bool,
    processed_index_path: Optional[Path] = None,
) -> None:
    processed_urls: set[str] = set()
    if processed_index_path is not None:
        processed_urls = load_processed_urls(processed_index_path)

    for url in urls:
        url = url.strip()
        if not url:
            continue

        if processed_index_path is not None and url in processed_urls:
            print(f"[skip] already processed: {url}")
            continue

        try:
            resp = reader.read_url(
                url,
                engine="browser",
                no_cache=True,
                respond_with="readerlm-v2" if readerlm_v2 else None,
            )
        except requests.exceptions.ReadTimeout:
            print(f"[timeout] {url}")
            continue
        except requests.exceptions.RequestException as e:
            print(f"[request error] {url} → {e}")
            continue
        except Exception as e:
            print(f"[error] {url} → {e}")
            continue

        data = resp.get("data", {}) if isinstance(resp, dict) else {}
        title = (data.get("title") or "").strip()
        content = (data.get("content") or "").strip()

        if not content:
            print(f"[empty] {url}")
            continue

        text_hash = sha256_text(content)
        doc_id = make_doc_id("web", url, text_hash)

        doc = RagDoc(
            doc_id=doc_id,
            source_type="web",
            source=url,
            title=title or url,
            text=content,
            fetched_at_utc=utc_now_iso(),
            sha256=text_hash,
            meta={
                "jina_status": resp.get("status"),
                "jina_code": resp.get("code"),
                "description": data.get("description"),
                "links": data.get("links"),
                "images": data.get("images"),
                "usage": data.get("usage"),
            },
        )

        write_doc(out_dir, doc)
        print(f"[web] wrote {doc_id}")

        if processed_index_path is not None:
            mark_url_processed(processed_index_path, url, doc_id, text_hash)
            processed_urls.add(url)  # avoid duplicates within the same run

# %%
base = Path.cwd()
web_dir = ensure_dirs(base)
# list of already-processed urls
processed_index = web_dir / "processed_urls.jsonl"

urls_dir = Path("urls")
url_files = sorted(urls_dir.glob("*.txt"))

urls = []

for txt_file in url_files:
    lines = [
        line.strip()
        for line in txt_file.read_text(encoding="utf-8").splitlines()
        if line.strip()
    ]
    for url in lines:
        urls.append(url)

print(f"Loaded {len(urls)} URLs from {len(url_files)} files")
# Out:
# Loaded 404 URLs from 4 files

# %%
# Use ReaderLM-v2 for higher-quality extraction (optional)
USE_READERLM_V2 = True
reader = JinaReader(api_key=api_key, eu=False, timeout_s=300)

for txt_file in url_files:
    urls = [
        line.strip()
        for line in txt_file.read_text(encoding="utf-8").splitlines()
        if line.strip()
    ]

    if not urls:
        continue

    print(f"\nProcessing batch: {txt_file.name} ({len(urls)} URLs)")

    ingest_web_urls(
        reader,
        urls,
        web_dir,
        readerlm_v2=USE_READERLM_V2,
        processed_index_path=processed_index,
    )
# Out:
# Processing batch: ai_act_annexes.txt (13 URLs)
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-1
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-2
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-3
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-4
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-5
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-6
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-7
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-8
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-9
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-10
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-11
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-12
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/annex-13
#
# Processing batch: ai_act_articles.txt (110 URLs)
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-1
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-2
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-3
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-4
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-5
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-6
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-7
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-8
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-9
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-10
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-11
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-12
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-13
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-14
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-15
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-16
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-17
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-18
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-19
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-20
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-21
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-22
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-23
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-24
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-25
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-26
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-27
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-28
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-29
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-30
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-31
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-32
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-33
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-34
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-35
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-36
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-37
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-38
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-39
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-40
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-41
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-42
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-43
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-44
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-45
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-46
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-47
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-48
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-49
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-50
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-51
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-52
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-53
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-54
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-55
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-56
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-57
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-58
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-59
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-60
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-61
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-62
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-63
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-64-3236465ed6b6
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-65
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-66
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-67
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-68
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-69
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-70
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-71
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-72
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-73
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-74
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-78
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-79
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-80
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-81
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-82
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-83
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-84
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-85
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-86
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-87
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-88
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-89
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-90
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-91
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-92
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-93
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-94
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-95
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-96
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-97
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-98
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-99
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-100
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-101
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-102
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-103
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-104
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-105
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-106
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-107
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-108-bee651c7604f
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-109
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-110
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-111
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-112
# [skip] already processed: https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-113
#
# Processing batch: ai_act_law_eu.txt (101 URLs)
# [skip] already processed: https://ai-act-law.eu/article/1/
# [skip] already processed: https://ai-act-law.eu/article/2/
# [skip] already processed: https://ai-act-law.eu/article/3/
# [skip] already processed: https://ai-act-law.eu/article/4/
# [skip] already processed: https://ai-act-law.eu/article/5/
# [skip] already processed: https://ai-act-law.eu/article/6/
# [skip] already processed: https://ai-act-law.eu/article/7/
# [skip] already processed: https://ai-act-law.eu/article/8/
# [skip] already processed: https://ai-act-law.eu/article/9/
# [skip] already processed: https://ai-act-law.eu/article/10/
# [skip] already processed: https://ai-act-law.eu/article/11/
# [skip] already processed: https://ai-act-law.eu/article/12/
# [skip] already processed: https://ai-act-law.eu/article/13/
# [skip] already processed: https://ai-act-law.eu/article/14/
# [skip] already processed: https://ai-act-law.eu/article/15/
# [skip] already processed: https://ai-act-law.eu/article/16/
# [skip] already processed: https://ai-act-law.eu/article/17/
# [skip] already processed: https://ai-act-law.eu/article/18/
# [skip] already processed: https://ai-act-law.eu/article/19/
# [skip] already processed: https://ai-act-law.eu/article/20/
# [skip] already processed: https://ai-act-law.eu/article/21/
