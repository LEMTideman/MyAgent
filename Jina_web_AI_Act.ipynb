# %% [markdown]
# ### Notebook for processing the AI Act available on the AI Act Explorer
#
# AI Act Explorer link: https://ai-act-service-desk.ec.europa.eu/en/ai-act-explorer
#
# Download the articles, recitals, and annexes using their respective urls.

# %%
from __future__ import annotations

import argparse
import hashlib
import json
import os
import re
import time
from dataclasses import dataclass, asdict
from pathlib import Path
from typing import Any, Dict, Iterable, List, Optional, Tuple

import requests
from dotenv import load_dotenv
import os

load_dotenv()  # loads .env from the current working directory

api_key = os.getenv("JINA_API_KEY")
if not api_key:
    raise RuntimeError("JINA_API_KEY not found in .env")

# %%
# ----------------------------
# Data model / utilities
# ----------------------------

@dataclass
class RagDoc:
    doc_id: str
    source_type: str          # "web" or "local_pdf"
    source: str               # URL or local path
    title: str
    text: str
    fetched_at_utc: str
    sha256: str
    meta: Dict[str, Any]


def utc_now_iso() -> str:
    return time.strftime("%Y-%m-%dT%H:%M:%SZ", time.gmtime())


def sha256_text(s: str) -> str:
    return hashlib.sha256(s.encode("utf-8", errors="ignore")).hexdigest()


def safe_slug(s: str, max_len: int = 80) -> str:
    s = s.strip().lower()
    s = re.sub(r"https?://", "", s)
    s = re.sub(r"[^a-z0-9]+", "-", s).strip("-")
    return s[:max_len] if s else "doc"


def ensure_dirs(base: Path) -> Tuple[Path, Path]:
    web_dir = base / "data" / "web"
    local_dir = base / "data" / "local"
    web_dir.mkdir(parents=True, exist_ok=True)
    local_dir.mkdir(parents=True, exist_ok=True)
    return web_dir, local_dir


def write_doc(out_dir: Path, doc: RagDoc) -> None:
    # Per-doc files
    json_path = out_dir / f"{doc.doc_id}.json"
    txt_path = out_dir / f"{doc.doc_id}.txt"

    with json_path.open("w", encoding="utf-8") as f:
        json.dump(asdict(doc), f, ensure_ascii=False, indent=2)

    with txt_path.open("w", encoding="utf-8") as f:
        f.write(doc.text or "")

    # Append to jsonl (easy bulk loading)
    jsonl_path = out_dir / "docs.jsonl"
    with jsonl_path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(asdict(doc), ensure_ascii=False) + "\n")


def make_doc_id(prefix: str, source: str, content_hash: str) -> str:
    slug = safe_slug(source)
    short = content_hash[:12] if content_hash else "nohash"
    return f"{prefix}-{slug}-{short}"

# %%
# ----------------------------
# Jina Reader client
# ----------------------------

class JinaReader:
    """
    Jina Reader API:
      - Read URL:    POST https://r.jina.ai/      JSON {"url": "..."}
      - Upload file: POST https://r.jina.ai/upload multipart field "file"
      - Request JSON response: Accept: application/json
      - Auth: Authorization: Bearer <JINA_API_KEY>
    """

    def __init__(self, api_key: str, eu: bool = False, timeout_s: int = 90):
        if not api_key:
            raise ValueError("JINA_API_KEY is required for Jina-only local PDF ingestion.")
        self.api_key = api_key
        self.timeout_s = timeout_s
        self.base = "https://eu.r.jina.ai" if eu else "https://r.jina.ai"

    def _headers(self, extra: Optional[Dict[str, str]] = None) -> Dict[str, str]:
        h = {
            "Accept": "application/json",
            "Authorization": f"Bearer {self.api_key}",
        }
        if extra:
            h.update(extra)
        return h

    def read_url(
        self,
        url: str,
        *,
        engine: str = "browser",
        no_cache: bool = True,
        respond_with: Optional[str] = None,  # e.g. "readerlm-v2"
        remove_selector: Optional[str] = None,
        target_selector: Optional[str] = None,
    ) -> Dict[str, Any]:
        headers: Dict[str, str] = {
            "Content-Type": "application/json",
            "X-Engine": engine,
            "X-No-Cache": "true" if no_cache else "false",
        }
        if respond_with:
            headers["X-Respond-With"] = respond_with
        if remove_selector:
            headers["X-Remove-Selector"] = remove_selector
        if target_selector:
            headers["X-Target-Selector"] = target_selector

        r = requests.post(
            f"{self.base}/",
            headers=self._headers(headers),
            json={"url": url},
            timeout=self.timeout_s,
        )
        r.raise_for_status()
        return r.json()

    def upload_pdf(
        self,
        pdf_path: Path,
        *,
        engine: str = "browser",
        no_cache: bool = True,
        respond_with: Optional[str] = None,
    ) -> Dict[str, Any]:
        headers: Dict[str, str] = {
            "X-Engine": engine,
            "X-No-Cache": "true" if no_cache else "false",
        }
        if respond_with:
            headers["X-Respond-With"] = respond_with

        with pdf_path.open("rb") as f:
            files = {"file": (pdf_path.name, f, "application/pdf")}
            r = requests.post(
                f"{self.base}/upload",
                headers=self._headers(headers),
                files=files,
                timeout=self.timeout_s,
            )
        r.raise_for_status()
        return r.json()

# %%
# ----------------------------
# Ingest routines (Jina-only)
# ----------------------------

import requests

def ingest_web_urls(
    reader: JinaReader,
    urls: Iterable[str],
    out_dir: Path,
    *,
    readerlm_v2: bool,
) -> None:
    for url in urls:
        url = url.strip()
        if not url:
            continue

        try:
            resp = reader.read_url(
                url,
                engine="browser",
                no_cache=True,
                respond_with="readerlm-v2" if readerlm_v2 else None,
            )
        except requests.exceptions.ReadTimeout:
            print(f"[timeout] {url}")
            continue
        except requests.exceptions.RequestException as e:
            # catches connection errors, SSL errors, etc.
            print(f"[request error] {url} → {e}")
            continue
        except Exception as e:
            # safety net: unexpected issues
            print(f"[error] {url} → {e}")
            continue

        data = resp.get("data", {}) if isinstance(resp, dict) else {}
        title = (data.get("title") or "").strip()
        content = (data.get("content") or "").strip()

        if not content:
            print(f"[empty] {url}")
            continue

        text_hash = sha256_text(content)
        doc_id = make_doc_id("web", url, text_hash)

        doc = RagDoc(
            doc_id=doc_id,
            source_type="web",
            source=url,
            title=title or url,
            text=content,
            fetched_at_utc=utc_now_iso(),
            sha256=text_hash,
            meta={
                "jina_status": resp.get("status"),
                "jina_code": resp.get("code"),
                "description": data.get("description"),
                "links": data.get("links"),
                "images": data.get("images"),
                "usage": data.get("usage"),
            },
        )

        write_doc(out_dir, doc)
        print(f"[web] wrote {doc_id}")

# %%
base = Path.cwd()
web_dir, local_dir = ensure_dirs(base)

reader = JinaReader(api_key=api_key, eu=False, timeout_s=300)  # set eu=True if needed

# %%
from pathlib import Path

urls_dir = Path("urls")

url_files = sorted(urls_dir.glob("*.txt"))

urls = []
url_sources = {}  # optional: track provenance

for txt_file in url_files:
    lines = [
        line.strip()
        for line in txt_file.read_text(encoding="utf-8").splitlines()
        if line.strip()
    ]
    for url in lines:
        urls.append(url)
        url_sources[url] = txt_file.name  # provenance

print(f"Loaded {len(urls)} URLs from {len(url_files)} files")
# Out:
# Loaded 110 URLs from 1 files

# %%
# Use ReaderLM-v2 for higher-quality extraction (optional)
USE_READERLM_V2 = True
#if urls:
#    ingest_web_urls(
#        reader,
#        urls,
#        web_dir,
#        readerlm_v2=USE_READERLM_V2,
#    )

for txt_file in url_files:
    urls = [
        line.strip()
        for line in txt_file.read_text(encoding="utf-8").splitlines()
        if line.strip()
    ]

    if not urls:
        continue

    print(f"\nProcessing batch: {txt_file.name} ({len(urls)} URLs)")

    ingest_web_urls(
        reader,
        urls,
        web_dir,
        readerlm_v2=USE_READERLM_V2,
        #batch_name=txt_file.stem,
    )
# Out:
# Processing batch: ai_act_articles.txt (110 URLs)
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-1-9cc59dae3877
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-2-bcc25e54270c
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-3-5c58cbfddeb9
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-4-75dada0dfb32
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-5-b85d78458a7d
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-6-e06175636de2
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-7-2b3058cc2a12
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-8-e8abb5ffed5f
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-9-fd92515c9913
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-10-ba8300d6c38f
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-11-1626e9995122
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-12-1d8e4b84ad73
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-13-48b9f9e04707
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-14-2c8cceaa75d9
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-15-cbd2699e8bdb
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-16-09cff1dc910e
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-17-4769ddde94ca
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-18-6abef7821e21
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-19-b2ee29a4c2d0
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-20-602003c03408
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-21-1ace2e34d356
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-22-cc15a9cda349
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-23-8d8d93628804
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-24-11ee6fee44e9
# [request error] https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-25 → 524 Server Error: <none> for url: https://r.jina.ai/
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-26-174094817b86
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-27-d0d775ce49cf
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-28-180256367276
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-29-9e8a14302513
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-30-06347cc5d003
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-31-4e9b3b948a09
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-32-cbf264c1541d
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-33-fd0e0bd55116
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-34-edc91dbf3b5f
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-35-9f7ac1c012db
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-36-d763c1e0144d
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-37-2ba204ba168f
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-38-09c278b6cb58
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-39-66485017ec0b
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-40-42b307166e6f
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-41-8dc0794c0a7f
# [request error] https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-42 → 503 Server Error: Service Unavailable for url: https://r.jina.ai/
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-43-75e84184c3e4
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-44-d313b659b130
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-45-81416d672cbb
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-46-af8a02f03dae
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-47-cdf09d0633af
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-48-09de82875ff7
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-49-4eda9b3192a5
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-50-50d8c332cf5a
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-51-db29f5761eb0
# [request error] https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-52 → 422 Client Error: Unprocessable Entity for url: https://r.jina.ai/
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-53-397bfa0542dd
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-54-f0c30d0d78c6
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-55-bda20d490102
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-56-539e79e3b7d1
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-57-d829a7c7b2dd
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-58-afc5f13fda10
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-59-c16337a817c6
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-60-c0bdda5f1593
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-61-6233de5861a3
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-62-c2172100627f
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-63-38447be67883
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-64-a729841a9b71
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-65-375afe8f50aa
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-66-cca6a235fb1e
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-67-4f22f271a59e
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-68-716da3eeb7cf
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-69-91dc16ac3455
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-70-75ab53aca488
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-71-34eced061229
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-72-360f6cd4da0c
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-73-5e3a14341d10
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-74-0e0ee1edfa34
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-78-e52ef57a50ba
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-79-5534845d869e
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-80-6195244c960b
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-81-ca01790d1bdb
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-82-c6c2aadc755b
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-83-91bbaec75b5d
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-84-e75eaef1afbc
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-85-0c60083e5f0d
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-86-478cf929e0b4
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-87-1eeb084687d4
# [request error] https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-88 → 524 Server Error: <none> for url: https://r.jina.ai/
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-89-5fdfc194fd43
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-90-be22b6303b68
# [request error] https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-91 → 503 Server Error: Service Unavailable for url: https://r.jina.ai/
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-92-ba4dfd007da1
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-93-0db54c19f3ef
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-94-0cd6d87a7540
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-95-652fa9c76416
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-96-6400e497ff81
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-97-43f65633ad55
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-98-c30159300f03
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-99-440ed1f9156f
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-100-e7e210bf9a35
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-101-1ac3b46a03fc
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-102-9a6cf962ddf4
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-103-10bf6e7a013a
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-104-8c64c37d5fe7
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-105-be31e344e192
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-106-6d74919fc5ff
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-107-ca1490c11d49
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-108-6244132ce285
# [request error] https://ai-act-service-desk.ec.europa.eu/en/ai-act/article-109 → 503 Server Error: Service Unavailable for url: https://r.jina.ai/
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-110-d511c2e57498
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-111-0fba23da3aef
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-112-0faac3a4b7cd
# [web] wrote web-ai-act-service-desk-ec-europa-eu-en-ai-act-article-113-49650f009712
